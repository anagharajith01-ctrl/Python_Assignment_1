# %%
a="Hello "
b=input("enter your name:")
c=a + b
print(c)
# Out:
# enter your name:Anu
# Hello Anu

# %%
d=", welcome to Python programming"
c =a + b + d
print(c)
# Out:
# Hello ann, welcome to Python programming

# %%
print(c[0])
# Out:
# H

# %%
print(c[-1])
# Out:
# g

# %%
print(c[0:5])
# Out:
# Hello

# %%
print(c[-11::])
# Out:
# programming

# %%
c1="".join(reversed(c))
print(c1)
# Out:
# gnimmargorp nohtyP ot emoclew ,nna olleH

# %%
print(c[-18:-12])
# Out:
# Python

# %%
strM = "Python beginner tutorial"

# %%
print(strM.upper())
# Out:
# PYTHON BEGINNER TUTORIAL

# %%
print(strM.lower())
# Out:
# python beginner tutorial

# %%
print(strM.capitalize())
# Out:
# Python beginner tutorial

# %%
print(strM.count("t"))
# Out:
# 3

# %%
print(strM.replace("Python","Machine Learning"))
# Out:
# Machine Learning beginner tutorial

# %%
t1=(10,20,30)
t2=(40,50,60)

# %%
t_combine=t1+t2
print(t_combine)
# Out:
# (10, 20, 30, 40, 50, 60)

# %%
print(t_combine*3)
# Out:
# (10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60)

# %%
print(t_combine[2])
# Out:
# 30

# %%
print(t_combine[0:3])
# Out:
# (10, 20, 30)

# %%
print(t_combine[-3:])
# Out:
# (40, 50, 60)
